# %%
import os

# %%
### summary 数据准备
os.system("awk '{print $2\"\t\"$4\"\t\"$5\"\t\"$7\"\t\"$11\"\t\"$12\"\t\"$13\"\t\"$6}' /home/wuxh/03.MultiPCancer/luohh/UKB50wMultiPcancer/03.result/04.3cancersMPCAllSite/fastGWA_GLMM_final.fastGWA > /home/wuxh/03.MultiPCancer/luohh/UKB50wMultiPcancer/03.result/04.3cancersMPCAllSite/02.GeneBaseGWAS/01.data/assoc.geneBased.txt")
# Out:
# 0
