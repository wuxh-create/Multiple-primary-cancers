# %%
import os
import math

# %%
cancerList = ["breast", "colorectal", "prostate", "lung", "melanoma", "urinaryBladder", "lymphoidNeoplasms", "cervix", 
             "kidney", "ovary", "otherDigestive", "uterus", "esophagus", "stomach", "myeloidNeoplasms", "headAndNeck", 
             "pancreas", "liver", "otherFemaleGenital", "tCellAndNKCellNeoplasms", "otherRespiratory", 
             "gallbladderAndBiliaryTract", "softTissueSarcoma", "otherUrinaryOrgans", "thyroid", "smallIntestine", "brain", 
             "anus", "eyeAndOrbit", "bone", "testis", "mesothelioma", "otherEndocrine"]

# %%
n = 0
for cancer in cancerList:
    n += 1
    num = "{:02}".format(n)
    os.system("head -n 1 /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/fastGWA_GLMM_final.fastGWA > /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/header.txt&")
    os.system("awk '{if($13<5e-6)print $0}' /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/fastGWA_GLMM_final.fastGWA > /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/sigGWA.5e-6.results&")
    os.system("awk '{if($13<5e-8)print $0}' /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/fastGWA_GLMM_final.fastGWA > /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/sigGWA.5e-8.results&")

# %%
n = 0
for cancer in cancerList:
    n += 1
    num = "{:02}".format(n)
    os.system("cat /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/header.txt /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/sigGWA.5e-6.results > /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/sigGWA.5e-6.header.results")
    os.system("cat /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/header.txt /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/sigGWA.5e-8.results > /home/luohh/UKB50wMultiPcancer/03.result/03.SpecificMPC/"+num+"."+cancer+
              "/sigGWA.5e-8.header.results")

# %%
print("{:02}".format(10))
# Out:
# 10

# %%
print(math.exp(1.75205))
# Out:
# 5.7664117116174225
