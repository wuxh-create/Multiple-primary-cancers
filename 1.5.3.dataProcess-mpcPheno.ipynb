# %%
### 生成 Multi P-cancer 表型文件
keepSample = {}
with open('/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/01.allPcancer/GWAS.last.sample',"r") as fi:
    for line in fi:
        data = line.strip()
        keepSample[data] = 0
fi.close()

fo = open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/01.allPcancer/GWAS.last.pheno","w")
with open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/01.allPcancer/GWAS.pheno","r") as fi:
    for line in fi:
        data = line.strip().split()
        if data[0] in keepSample:
            fo.write(line)
fi.close()
fo.close()

# %%
### 生成 lung - Digestive Cancer 表型文件
keepSample = {}
with open('/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/02.lungDigestiveCancer/GWAS.last.sample',"r") as fi:
    for line in fi:
        data = line.strip()
        keepSample[data] = 0
fi.close()

fo = open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/02.lungDigestiveCancer/GWAS.last.pheno","w")
with open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/02.lungDigestiveCancer/GWAS.pheno","r") as fi:
    for line in fi:
        data = line.strip().split()
        if data[0] in keepSample:
            fo.write(line)
fi.close()
fo.close()

# %%
### 生成 Multi P-cancer Rare 表型文件
keepSample = {}
with open('/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/03.allPcancerRare/GWAS.last.sample',"r") as fi:
    for line in fi:
        data = line.strip()
        keepSample[data] = 0
fi.close()

fo = open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/03.allPcancerRare/GWAS.last.pheno","w")
with open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/03.allPcancerRare/GWAS.pheno","r") as fi:
    for line in fi:
        data = line.strip().split()
        if data[0] in keepSample:
            fo.write(line)
fi.close()
fo.close()

# %%
### 生成 lung - Digestive Cancer Rare 表型文件
keepSample = {}
with open('/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/04.lungDigestiveCancerRare/GWAS.last.sample',"r") as fi:
    for line in fi:
        data = line.strip()
        keepSample[data] = 0
fi.close()

fo = open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/04.lungDigestiveCancerRare/GWAS.last.pheno","w")
with open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/04.lungDigestiveCancerRare/GWAS.pheno","r") as fi:
    for line in fi:
        data = line.strip().split()
        if data[0] in keepSample:
            fo.write(line)
fi.close()
fo.close()

# %%
### 流程代码块
import sys

keepSample = {}
with open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/05.otherSpecificPcancer/"+sys.argv[1]+"/GWAS.last.sample","r") as fi:
    for line in fi:
        data = line.strip()
        keepSample[data] = 0
fi.close()

fo = open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/05.otherSpecificPcancer/"+sys.argv[1]+"/GWAS.last.pheno","w")
with open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/05.otherSpecificPcancer/"+sys.argv[1]+"/GWAS.pheno","r") as fi:
    for line in fi:
        data = line.strip().split()
        if data[0] in keepSample:
            fo.write(line)
fi.close()
fo.close()

# %%
import sys

### 取特有性别样本
sexDict = {}
with open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/basic.pheno","r") as fi:
    for line in fi:
        data = line.strip().split("\t")
        if data[1] == "male":
            sexDict[data[0]] = "M"
        elif data[1] == "female":
            sexDict[data[0]] = "F"
fi.close()

fo = open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/05.otherSpecificPcancer/"+sys.argv[1]+"/GWAS.last.sample","w")
with open("/home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/05.otherSpecificPcancer/"+sys.argv[1]+"/GWAS.sample","r") as fi:
    for line in fi:
        sampleid = line.strip()
        if sys.argv[2] == "female" and sexDict[sampleid] == "F":
            fo.write(sampleid+"\n")
        elif sys.argv[2] == "male" and sexDict[sampleid] == "M":
            fo.write(sampleid+"\n")
        elif sys.argv[2] == "allSex":
            fo.write(sampleid+"\n")
fi.close()
fo.close()
