# %%
import os

# %%
os.system("cat /home/luohh/UKB50wMultiPcancer/01.data/04.sampleData/04.cancerGroup/03.whiteData/*.filtered.white.sample | sort | uniq -c | awk '{if($1>3)print $2}' > /home/luohh/UKB50wMultiPcancer/01.data/02.phenoData/05.4cancersMPC/4cancersMPC.sample")
# Out:
# 0
